# %%
import os
os.listdir()
# Out:
# ['regionxi_address.csv',
#  'data',
#  'geocode.ipynb',
#  '.ipynb_checkpoints',
#  'regionxi.csv',
#  'batch_geocode.py',
#  'pandas.ipynb',
#  'add_address.py',
#  'geocode_trial.py',
#  'orig_data.xlsx']

# %%
import pandas
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
df = pandas.read_csv("data/test.csv")

cols = ['name', 'city', 'submun', 'province']
df["address"] = df[cols].apply(lambda x: ','.join(x.dropna()), axis=1)
df
# Out:
#         code       name  submun            city        province  \
# 0  112402087    Panacan     NaN           Davao   Davao Del Sur
# 1  126303024   San Jose     NaN  General Santos  South Cotabato
# 2  126303026    Sinawal     NaN  General Santos  South Cotabato
# 3  126303027    Tambler     NaN  General Santos  South Cotabato
# 4  126303028  Tinagacan     NaN  General Santos  South Cotabato
#
#                                    address
# 0              Panacan,Davao,Davao Del Sur
# 1   San Jose,General Santos,South Cotabato
# 2    Sinawal,General Santos,South Cotabato
# 3    Tambler,General Santos,South Cotabato
# 4  Tinagacan,General Santos,South Cotabato

# %%
df
# Out:
#         code       name  submun            city        province  \
# 0  112402087    Panacan     NaN           Davao   Davao Del Sur
# 1  126303024   San Jose     NaN  General Santos  South Cotabato
# 2  126303026    Sinawal     NaN  General Santos  South Cotabato
# 3  126303027    Tambler     NaN  General Santos  South Cotabato
# 4  126303028  Tinagacan     NaN  General Santos  South Cotabato
#
#                                    address
# 0              Panacan,Davao,Davao Del Sur
# 1   San Jose,General Santos,South Cotabato
# 2    Sinawal,General Santos,South Cotabato
# 3    Tambler,General Santos,South Cotabato
# 4  Tinagacan,General Santos,South Cotabato

# %%
df.to_csv('data/test1.csv')
